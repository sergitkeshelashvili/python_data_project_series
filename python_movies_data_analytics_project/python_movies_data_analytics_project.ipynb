# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('movies_raw_data.csv')
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df = df.drop(columns = ['id', 'imdb_id', 'homepage', 'cast', 'tagline', 'overview', 'budget_adj'])
df.head()
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#            director                                           keywords  \
# 0   Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 1     George Miller   future|chase|post-apocalyptic|dystopia|australia
# 2  Robert Schwentke  based on novel|revolution|dystopia|sequel|dyst...
# 3       J.J. Abrams              android|spaceship|jedi|space opera|3d
# 4         James Wan                car race|speed|revenge|suspense|car
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# ...

# %%
df.isnull().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# director                  44
# keywords                1493
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# revenue_adj                0
# dtype: int64

# %%
df = df.dropna(how = 'any', subset = ['genres', 'director'])

# %%
df['production_companies'] = df['production_companies'].fillna(0)
df['keywords'] = df['keywords'].fillna(0)
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_2880\1975102850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['production_companies'] = df['production_companies'].fillna(0)
# C:\Users\sergi\AppData\Local\Temp\ipykernel_2880\1975102850.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['keywords'] = df['keywords'].fillna(0)

# %%
df.isnull().sum()
# Out:
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# director                0
# keywords                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# revenue_adj             0
# dtype: int64

# %%
df['popularity'] = df['popularity'].round(2)
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_2880\916718365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['popularity'] = df['popularity'].round(2)

# %%
df.insert(3, 'profit', df.revenue - df.budget)
# Out:
#    popularity     budget     revenue      profit  \
# 0       32.99  150000000  1513528810  1363528810
# 1       28.42  150000000   378436354   228436354
# 2       13.11  110000000   295238201   185238201
# 3       11.17  200000000  2068178225  1868178225
# 4        9.34  190000000  1506249360  1316249360
#
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 1            Mad Max: Fury Road     George Miller
# 2                     Insurgent  Robert Schwentke
# 3  Star Wars: The Force Awakens       J.J. Abrams
# 4                     Furious 7         James Wan
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island      124
# 1   future|chase|post-apocalyptic|dystopia|australia      120
# 2  based on novel|revolution|dystopia|sequel|dyst...      119
# 3              android|spaceship|jedi|space opera|3d      136
# ...

# %%
df.insert(4, 'roi', df.profit / df.budget)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2880\2759673087.py in ?()
# ----> 1 df.insert(4, 'roi', df.profit / df.budget)
#
# c:\Users\sergi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#    5161         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert roi, already exists

# %%
df['roi'] = df['roi'].round(2)
df.head()
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_2880\295577314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['roi'] = df['roi'].round(2)
#    popularity     budget     revenue      profit   roi  \
# 0       32.99  150000000  1513528810  1363528810  9.09
# 1       28.42  150000000   378436354   228436354  1.52
# 2       13.11  110000000   295238201   185238201  1.68
# 3       11.17  200000000  2068178225  1868178225  9.34
# 4        9.34  190000000  1506249360  1316249360  6.93
#
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 1            Mad Max: Fury Road     George Miller
# 2                     Insurgent  Robert Schwentke
# ...

# %%
df.roi.value_counts()
# Out:
# roi
# -1.00     1350
#  inf       995
# -0.99       29
# -0.98       27
# -0.38       21
#           ...
#  14.63       1
#  16.65       1
#  7.38        1
#  6.95        1
#  10.06       1
# Name: count, Length: 1075, dtype: int64

# %%
non_finite_values = ~np.isfinite(df['roi'])

# %%
non_finite_values.sum()
# Out:
# np.int64(5636)

# %%
df['roi'] = df['roi'].replace([np.inf, -np.inf], np.nan)
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_2880\3210443886.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['roi'] = df['roi'].replace([np.inf, -np.inf], np.nan)

# %%
df1 = df [['popularity', 'budget', 'revenue', 'profit', 'roi', 'vote_count', 'release_year']]

# %%
print(df1.isin([np.inf, -np.inf]).any())  # Check for infinite values
print(df1.isna().any())                   # Check for NaN values
# Out:
# popularity      False
# budget          False
# revenue         False
# profit          False
# roi              True
# vote_count      False
# release_year    False
# dtype: bool
# popularity      False
# budget          False
# revenue         False
# profit          False
# roi              True
# vote_count      False
# release_year    False
# dtype: bool

# %%
numeric_cols = df1.select_dtypes(include=np.number).columns
print("Columns with infinite values:")
print(df1[numeric_cols].isin([np.inf, -np.inf]).any())
# Out:
# Columns with infinite values:
# popularity      False
# budget          False
# revenue         False
# profit          False
# roi              True
# vote_count      False
# release_year    False
# dtype: bool

# %%
print("Columns with NaN values:")
print(df1[numeric_cols].isna().any())
# Out:
# Columns with NaN values:
# popularity      False
# budget          False
# revenue         False
# profit          False
# roi              True
# vote_count      False
# release_year    False
# dtype: bool

# %%
df1_clean = df1[numeric_cols].replace([np.inf, -np.inf], np.nan).dropna()

# %%
df1_clean = df1[numeric_cols].replace([np.inf, -np.inf], np.nan)
df1_clean = df1_clean.fillna(df1_clean.mean())  # Or use a specific value, e.g., 0

# %%
df1_clean.hist(bins=20, figsize=(14,12))
plt.show()

# %%
df2 = df.groupby('release_year')['roi'].mean()
df2.plot(kind = 'line')
# Out:
# <Axes: xlabel='release_year'>

# %%
df3 = df.groupby('release_year')['popularity'].sum().plot(kind = 'line', color = 'red')
plt.xlabel('Year', fontsize=12)
plt.ylabel('popularity', fontsize=12)
# Out:
# Text(0, 0.5, 'popularity')

# %%
df4 = df.groupby('release_year')['vote_average'].mean()
df4.plot(kind = 'line', color = 'green')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Rating', fontsize=12)
# Out:
# Text(0, 0.5, 'Rating')

# %%
df5 = df.plot.scatter(x = 'popularity', y = 'vote_average', c = 'green', figsize=(6,4))

# %%
split = ['genres']
for i in split:
    df[i] = df[i].apply(lambda x: x.split('|'))
df.head()
# Out:
#    popularity     budget     revenue      profit   roi  \
# 0       32.99  150000000  1513528810  1363528810  9.09
# 1       28.42  150000000   378436354   228436354  1.52
# 2       13.11  110000000   295238201   185238201  1.68
# 3       11.17  200000000  2068178225  1868178225  9.34
# 4        9.34  190000000  1506249360  1316249360  6.93
#
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 1            Mad Max: Fury Road     George Miller
# 2                     Insurgent  Robert Schwentke
# 3  Star Wars: The Force Awakens       J.J. Abrams
# 4                     Furious 7         James Wan
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island      124
# 1   future|chase|post-apocalyptic|dystopia|australia      120
# 2  based on novel|revolution|dystopia|sequel|dyst...      119
# 3              android|spaceship|jedi|space opera|3d      136
# ...

# %%
df = df.explode('genres')
df
# Out:
#        popularity     budget     revenue      profit   roi  \
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 1           28.42  150000000   378436354   228436354  1.52
# ...           ...        ...         ...         ...   ...
# 10863        0.07          0           0           0   NaN
# 10863        0.07          0           0           0   NaN
# 10864        0.06          0           0           0   NaN
# 10864        0.06          0           0           0   NaN
# 10865        0.04      19000           0      -19000 -1.00
#
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# ...

# %%
df7 = df.groupby('genres')['popularity'].sum().sort_values(ascending=True)
df7
# Out:
# genres
# Foreign              35.24
# TV Movie             44.03
# Documentary          93.13
# Western              97.42
# History             192.35
# War                 196.48
# Music               198.15
# Mystery             558.55
# Animation           594.46
# Horror              761.39
# Fantasy             908.87
# Family              967.06
# Crime              1009.07
# Romance            1013.21
# Science Fiction    1230.41
# Adventure          1697.11
# Thriller           2155.90
# Action             2208.08
# Comedy             2246.25
# Drama              2815.43
# Name: popularity, dtype: float64

# %%
df7.plot.barh(x = 'genres', y = 'popularity', color = 'blue', figsize=(12,6))
# Out:
# <Axes: ylabel='genres'>

# %%
df.dtypes
# Out:
# popularity              float64
# budget                    int64
# revenue                   int64
# profit                    int64
# roi                     float64
# original_title           object
# director                 object
# keywords                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# revenue_adj             float64
# dtype: object

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df.head()
# Out:
# C:\Users\sergi\AppData\Local\Temp\ipykernel_2880\2357862039.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['release_date'] = pd.to_datetime(df['release_date'])
#    popularity     budget     revenue      profit   roi      original_title  \
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 1       28.42  150000000   378436354   228436354  1.52  Mad Max: Fury Road
#
#           director                                           keywords  \
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# ...

# %%
df['extracted_month'] = df['release_date'].dt.month
df.head()
# Out:
#    popularity     budget     revenue      profit   roi      original_title  \
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 1       28.42  150000000   378436354   228436354  1.52  Mad Max: Fury Road
#
#           director                                           keywords  \
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 1    George Miller   future|chase|post-apocalyptic|dystopia|australia
#
#    runtime           genres  \
# 0      124           Action
# 0      124        Adventure
# ...

# %%
df8 = df.groupby('extracted_month')['popularity'].sum()

# %%
data = {
    'extracted_month': df8.index,
    'popularity': df8.values
}
df8 = pd.DataFrame(data)

# %%
df8
# Out:
#     extracted_month  popularity
# 0                 1     1131.78
# 1                 2     1092.93
# 2                 3     1458.32
# 3                 4     1191.81
# 4                 5     1687.53
# 5                 6     1936.84
# 6                 7     1694.03
# 7                 8     1432.59
# 8                 9     1872.28
# 9                10     1811.91
# 10               11     1710.35
# 11               12     2002.22

# %%
index_to_month = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}

# %%
df8.extracted_month = df8.extracted_month.map(index_to_month)

# %%
df8
# Out:
#    extracted_month  popularity
# 0          January     1131.78
# 1         February     1092.93
# 2            March     1458.32
# 3            April     1191.81
# 4              May     1687.53
# 5             June     1936.84
# 6             July     1694.03
# 7           August     1432.59
# 8        September     1872.28
# 9          October     1811.91
# 10        November     1710.35
# 11        December     2002.22

# %%
df8.plot(kind='bar', x='extracted_month', y='popularity', color='darkblue', figsize=(12, 6))
# Out:
# <Axes: xlabel='extracted_month'>

# %%
df9 = df.groupby('extracted_month')['revenue'].sum()
df9
# Out:
# extracted_month
# 1      35873456579
# 2      54352852344
# 3      93669046441
# 4      77813179749
# 5     151475532493
# 6     193681776686
# 7     141947570995
# 8      71642408883
# 9      70379641581
# 10     84054172048
# 11    139176268899
# 12    164738399960
# Name: revenue, dtype: int64

# %%
data = {
    'extracted_month': df9.index,
    'revenue': df9.values
}
df9 = pd.DataFrame(data)

# %%
index_to_month = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}

# %%
df9.extracted_month = df9.extracted_month.map(index_to_month)

# %%
df9.plot(kind='bar', x='extracted_month', y='revenue', color='darkblue', figsize=(12, 6))
plt.title('Monthly revenue of movies', fontsize=16)
plt.xlabel('Revenue', fontsize=12)
plt.ylabel('Month', fontsize=12)
plt.show()

# %%
df10 = df.groupby('original_title')['profit'].sum().sort_values(ascending=False).head(10)
df10
# Out:
# original_title
# Avatar                                          10178023388
# Star Wars: The Force Awakens                     7472712900
# Jurassic World                                   5454115240
# The Net                                          5421398290
# Titanic                                          4896102564
# Minions                                          4330923848
# Furious 7                                        3948748080
# The Avengers                                     3887196562
# Shrek 2                                          3849193790
# Harry Potter and the Deathly Hallows: Part 2     3608453466
# Name: profit, dtype: int64

# %%
df10.plot(kind='pie', autopct='%1.1f%%', figsize=(10, 8), title='Top 10 Movies by Profit', colors=px.colors.qualitative.Plotly)
# Out:
# <Axes: title={'center': 'Top 10 Movies by Profit'}, ylabel='profit'>

# %%
df.to_csv('python_data_cleaning_visualization.csv', index=False)
